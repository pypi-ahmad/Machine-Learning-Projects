# %% [markdown]
# # Garbage Classification using PyTorch
#
# Garbage segregation involves separating wastes according to how it's handled or processed. It's important for recycling as some materials are recyclable and others are not.
#
#
# ![Garbage Bins](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fwebstockreview.net%2Fimages%2Fgarbage-clipart-wastebin-16.png&f=1&nofb=1)
#
#
# In this notebook we'll use PyTorch for classifying trash into various categories like metal, cardboard, etc.

# %% [markdown]
# Let us start by importing the libraries:

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\programdata\anaconda3\envs\epam\lib\site-packages (1.13.1)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\envs\epam\lib\site-packages (from torch) (3.7.4.3)

# %%
# !pip install torchvision
# Out:
# Requirement already satisfied: torchvision in c:\programdata\anaconda3\envs\epam\lib\site-packages (0.14.1)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\envs\epam\lib\site-packages (from torchvision) (3.7.4.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\programdata\anaconda3\envs\epam\lib\site-packages (from torchvision) (9.1.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\epam\lib\site-packages (from torchvision) (2.26.0)
# Requirement already satisfied: torch==1.13.1 in c:\programdata\anaconda3\envs\epam\lib\site-packages (from torchvision) (1.13.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\epam\lib\site-packages (from torchvision) (1.20.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\epam\lib\site-packages (from requests->torchvision) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\epam\lib\site-packages (from requests->torchvision) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\envs\epam\lib\site-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\epam\lib\site-packages (from requests->torchvision) (3.3)

# %%
import os
import torch
import torchvision
from torch.utils.data import random_split
import torchvision.models as models
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# Let us see the classes present in the dataset:

# %%
data_dir  = './archive/Garbage classification/Garbage classification'

classes = os.listdir(data_dir)
print(classes)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# ## Transformations:

# %% [markdown]
# Now, let's apply transformations to the dataset and import it for use.

# %%
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

transformations = transforms.Compose([transforms.Resize((256, 256)), transforms.ToTensor()])

dataset = ImageFolder(data_dir, transform = transformations)

# %% [markdown]
# Let's create a helper function to see the image and its corresponding label:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def show_sample(img, label):
    print("Label:", dataset.classes[label], "(Class No: "+ str(label) + ")")
    plt.imshow(img.permute(1, 2, 0))

# %%
img, label = dataset[12]
show_sample(img, label)
# Out:
# Label: cardboard (Class No: 0)

# %% [markdown]
# # Loading and Splitting Data:
