# %% [markdown]
# # Advertising Sales Prediction
#
# **Tabular Regression Project** — Predict product sales from advertising spend across multiple channels.
#
# Models: CatBoost · LightGBM · XGBoost
# Baselines: LazyPredict · FLAML AutoML
# Target: `sales`

# %% [markdown]
# ## 2 · Project Overview
#
# We predict **product sales** from advertising spend across multiple channels (TV, radio, digital, social media, print). This classic marketing-mix modeling problem captures the **diminishing returns** of ad spend and helps optimize budget allocation.

# %% [markdown]
# ## 3 · Learning Objectives
#
# By the end of this notebook you will be able to:
# 1. Perform EDA on a tabular regression dataset.
# 2. Build a baseline Linear Regression model.
# 3. Benchmark many regressors with LazyPredict.
# 4. Run FLAML AutoML for automated model selection.
# 5. Train CatBoost, LightGBM, and XGBoost with GPU auto-detection.
# 6. Evaluate with RMSE, MAE, R² and residual analysis.
# 7. Compare all models and select the top 3.

# %% [markdown]
# ## 4 · Problem Statement
#
# Given advertising budgets across TV, radio, digital, social, and print channels — plus season, region, product category, competitor spend, and brand awareness — predict the **resulting sales** in dollars.

# %% [markdown]
# ## 5 · Why This Project Matters
#
# - **Marketing-mix modeling (MMM)** is a multi-billion dollar industry.
# - Understanding **channel effectiveness** enables optimal budget allocation.
# - **Diminishing returns** mean doubling spend rarely doubles sales.
# - **Competitor spend** affects your ROI — the model captures competitive dynamics.
# - A foundational data science problem in digital marketing and CPG.

# %% [markdown]
# ## 6 · Dataset Overview
#
# | Property | Value |
# |----------|-------|
# | **Rows** | 7,500 |
# | **Features** | 10 (TV, radio, digital, social, print spend, season, region, category, competitor spend, brand awareness) |
# | **Target** | `sales` (continuous, USD) |
# | **Categorical** | season (4), region (4), product_category (4) |
# | **Missing** | None |

# %% [markdown]
# ## 7 · Dataset Source and License Notes
#
# - **Source**: Synthetic dataset generated for educational purposes.
# - **License**: Free for learning and experimentation.
# - **Limitations**: Simulated data — real-world relationships may be more complex.

# %% [markdown]
# ## 8 · Environment Setup
#
# Install any missing packages. GPU is auto-detected with CPU fallback.

# %%
import subprocess, sys

def _install(pkg):
    try:
        __import__(pkg)
    except ImportError:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", pkg])

for pkg in ["catboost", "lightgbm", "xgboost", "flaml", "lazypredict"]:
    _install(pkg)

print("All packages ready.")

# %% [markdown]
# ## 9 · Imports

# %%
import os, json, time, warnings, random, gc
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, root_mean_squared_error

warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
print("Imports complete.")

# %% [markdown]
# ## 10 · Configuration / Constants

# %%
TARGET = "sales"
SAVE_DIR = os.path.dirname(os.path.abspath("__file__"))
print(f"Target: {TARGET}")
print(f"Save dir: {SAVE_DIR}")

# %% [markdown]
# ## 11 · Dataset Download or Loading
#
# We generate a synthetic dataset so the notebook is fully self-contained.

# %%
np.random.seed(42)
n = 7500
tv_spend = np.random.uniform(0, 300000, n)
radio_spend = np.random.uniform(0, 60000, n)
digital_spend = np.random.uniform(0, 150000, n)
social_spend = np.random.uniform(0, 80000, n)
print_spend = np.random.uniform(0, 50000, n)
season = np.random.choice(["spring", "summer", "fall", "winter"], n)
region = np.random.choice(["north", "south", "east", "west"], n)
product_cat = np.random.choice(["electronics", "apparel", "food", "home"], n)
competitor_spend = np.random.uniform(10000, 200000, n)
brand_awareness_idx = np.random.uniform(20, 95, n)

# Diminishing returns via sqrt
sales = (np.sqrt(tv_spend) * 15 + np.sqrt(radio_spend) * 12
         + np.sqrt(digital_spend) * 18 + np.sqrt(social_spend) * 10
         + np.sqrt(print_spend) * 5
         + brand_awareness_idx * 50
         - np.sqrt(competitor_spend) * 3
         + np.random.normal(0, 500, n))
sales = np.maximum(sales, 100)

df = pd.DataFrame({
    "tv_spend": tv_spend, "radio_spend": radio_spend,
    "digital_spend": digital_spend, "social_media_spend": social_spend,
    "print_spend": print_spend, "season": season,
    "region": region, "product_category": product_cat,
    "competitor_ad_spend": competitor_spend,
    "brand_awareness_index": brand_awareness_idx,
    "sales": sales
})
print(f"Generated dataset: {df.shape}")
df.head()

# %% [markdown]
# ## 12 · Data Validation Checks

# %%
print("=" * 50)
print("DATA VALIDATION")
print("=" * 50)
print(f"\nShape: {df.shape}")
print(f"\nMissing values:\n{df.isnull().sum()}")
print(f"\nDuplicate rows: {df.duplicated().sum()}")
print(f"\nDtypes:\n{df.dtypes}")
assert TARGET in df.columns, f"Target '{TARGET}' not found!"
print(f"\nTarget '{TARGET}' confirmed.")

# %% [markdown]
# ## 13 · Exploratory Data Analysis

# %%
df.describe()

# %%
num_cols = df.select_dtypes(include="number").columns.tolist()
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(df[num_cols].corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0, ax=ax, square=True)
ax.set_title("Feature Correlation Heatmap")
plt.tight_layout(); plt.show()

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
for i, col in enumerate(["tv_spend", "digital_spend", "radio_spend",
                          "social_media_spend", "brand_awareness_index", "competitor_ad_spend"]):
    ax = axes[i // 3, i % 3]
    ax.scatter(df[col], df["sales"], alpha=0.2, s=8)
    ax.set_xlabel(col); ax.set_ylabel("sales"); ax.set_title(f"Sales vs {col}")
plt.tight_layout(); plt.show()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
df.groupby("season")["sales"].mean().plot(
    kind="bar", ax=axes[0], color="steelblue", edgecolor="black")
axes[0].set_title("Mean Sales by Season"); axes[0].set_ylabel("Sales ($)")
df.groupby("product_category")["sales"].mean().sort_values().plot(
    kind="barh", ax=axes[1], color="darkorange", edgecolor="black")
axes[1].set_title("Mean Sales by Product Category")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 14 · Target Analysis
#
# Examine the distribution of `sales`.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
axes[0].hist(df[TARGET], bins=40, color="steelblue", edgecolor="black", alpha=0.8)
axes[0].set_title(f"Distribution of {TARGET}"); axes[0].set_xlabel("Sales ($)")
axes[1].boxplot(df[TARGET], vert=True); axes[1].set_title(f"Box Plot of {TARGET}")
plt.tight_layout(); plt.show()
print(f"Mean: ${df[TARGET].mean():,.0f}, Median: ${df[TARGET].median():,.0f}")
print(f"Std: ${df[TARGET].std():,.0f}, Range: ${df[TARGET].min():,.0f} - ${df[TARGET].max():,.0f}")

# %% [markdown]
# ## 15 · Train/Validation/Test Split Strategy
#
# 80/20 train/test split with a fixed random seed for reproducibility.

# %%
from sklearn.preprocessing import OrdinalEncoder

X = df.drop(columns=[TARGET])
y = df[TARGET]

cat_cols = X.select_dtypes(include="object").columns.tolist()
oe = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)
X[cat_cols] = oe.fit_transform(X[cat_cols])

X.columns = [c.replace(" ", "_").replace("-", "_").replace(".", "_") for c in X.columns]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)
print(f"Train: {X_train.shape}, Test: {X_test.shape}")

# %% [markdown]
# ## 16 · Preprocessing Strategy
#
# - **Missing values**: None in this synthetic dataset.
# - **Categorical**: Encoded via OrdinalEncoder.
# - **Scaling**: Not required for tree-based models.
# - **Outliers**: Handled during generation.

# %% [markdown]
# ## 17 · Feature Engineering

# %%
X_train = X_train.copy(); X_test = X_test.copy()

# Sqrt transforms to capture diminishing returns
for col in ["tv_spend", "digital_spend", "radio_spend", "social_media_spend", "print_spend"]:
    X_train[f"sqrt_{col}"] = np.sqrt(X_train[col])
    X_test[f"sqrt_{col}"] = np.sqrt(X_test[col])

X_train["total_ad_spend"] = X_train[["tv_spend", "digital_spend", "radio_spend",
                                      "social_media_spend", "print_spend"]].sum(axis=1)
X_test["total_ad_spend"] = X_test[["tv_spend", "digital_spend", "radio_spend",
                                    "social_media_spend", "print_spend"]].sum(axis=1)

print(f"Features ({X_train.shape[1]}): {list(X_train.columns)}")

# %% [markdown]
# ## 18 · Baseline Model
#
# Linear Regression provides a simple, interpretable baseline.

# %%
baseline = LinearRegression()
baseline.fit(X_train, y_train)
y_pred_bl = baseline.predict(X_test)

rmse_bl = root_mean_squared_error(y_test, y_pred_bl)
mae_bl = mean_absolute_error(y_test, y_pred_bl)
r2_bl = r2_score(y_test, y_pred_bl)

print("=" * 50)
print("BASELINE: Linear Regression")
print("=" * 50)
print(f"RMSE : {rmse_bl:,.2f}")
print(f"MAE  : {mae_bl:,.2f}")
print(f"R2   : {r2_bl:.4f}")

# %% [markdown]
# ## 19 · LazyPredict Benchmark
#
# Quickly rank dozens of regressors.

# %%
from lazypredict.Supervised import LazyRegressor

lazy = LazyRegressor(verbose=0, ignore_warnings=True)
lazy_models, _ = lazy.fit(X_train, X_test, y_train, y_test)

print("LazyPredict — Top 10 Regressors:")
print(lazy_models.head(10).to_string())

# %% [markdown]
# ## 20 · FLAML AutoML Run
#
# Automated model selection and hyperparameter tuning (60 s budget).

# %%
from flaml import AutoML

try:
    flaml_automl = AutoML()
    flaml_automl.fit(X_train, y_train, task="regression", time_budget=60,
                     estimator_list=["lgbm", "rf", "extra_tree", "catboost"],
                     verbose=0, seed=SEED)
    y_pred_flaml = flaml_automl.predict(X_test)
    rmse_flaml = root_mean_squared_error(y_test, y_pred_flaml)
    r2_flaml = r2_score(y_test, y_pred_flaml)
    print(f"FLAML best model: {flaml_automl.best_estimator}")
    print(f"RMSE: {rmse_flaml:,.2f}")
    print(f"R2  : {r2_flaml:.4f}")
except Exception as e:
    print(f"FLAML error: {e}")
    y_pred_flaml = y_pred_bl

# %% [markdown]
# ## 21 · Additional Models: CatBoost, LightGBM, XGBoost
#
# Train the modern gradient-boosting stack. GPU auto-detected with CPU fallback.

# %%
def gpu_cleanup():
    gc.collect()
    try:
        import torch; torch.cuda.empty_cache()
    except Exception:
        pass

results = {}
timings = {}

# --- CatBoost ---
try:
    from catboost import CatBoostRegressor
    t0 = time.perf_counter()
    try:
        cb = CatBoostRegressor(iterations=500, learning_rate=0.05, depth=6,
                               task_type="GPU", devices="0", verbose=0, random_seed=SEED)
        cb.fit(X_train, y_train, eval_set=(X_test, y_test), early_stopping_rounds=50)
    except Exception:
        cb = CatBoostRegressor(iterations=500, learning_rate=0.05, depth=6,
                               verbose=0, random_seed=SEED)
        cb.fit(X_train, y_train, eval_set=(X_test, y_test), early_stopping_rounds=50)
    timings["CatBoost"] = time.perf_counter() - t0
    results["CatBoost"] = cb.predict(X_test)
    print(f"CatBoost RMSE: {root_mean_squared_error(y_test, results['CatBoost']):,.2f}  ({timings['CatBoost']:.1f}s)")
except Exception as e:
    print(f"CatBoost failed: {e}")
gpu_cleanup()

# --- LightGBM ---
try:
    import lightgbm as lgb
    t0 = time.perf_counter()
    try:
        lg = lgb.LGBMRegressor(n_estimators=500, learning_rate=0.05, max_depth=6,
                               device="gpu", verbose=-1, n_jobs=-1, random_state=SEED)
        lg.fit(X_train, y_train, eval_set=[(X_test, y_test)],
               callbacks=[lgb.early_stopping(50), lgb.log_evaluation(0)])
    except Exception:
        lg = lgb.LGBMRegressor(n_estimators=500, learning_rate=0.05, max_depth=6,
                               device="cpu", verbose=-1, n_jobs=-1, random_state=SEED)
        lg.fit(X_train, y_train, eval_set=[(X_test, y_test)],
               callbacks=[lgb.early_stopping(50), lgb.log_evaluation(0)])
    timings["LightGBM"] = time.perf_counter() - t0
    results["LightGBM"] = lg.predict(X_test)
    print(f"LightGBM RMSE: {root_mean_squared_error(y_test, results['LightGBM']):,.2f}  ({timings['LightGBM']:.1f}s)")
except Exception as e:
    print(f"LightGBM failed: {e}")
gpu_cleanup()

# --- XGBoost ---
try:
    from xgboost import XGBRegressor
    t0 = time.perf_counter()
    try:
        xgb_model = XGBRegressor(n_estimators=500, learning_rate=0.05, max_depth=6,
                                 device="cuda", tree_method="hist", verbosity=0,
                                 n_jobs=-1, random_state=SEED)
        xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)],
                      early_stopping_rounds=50, verbose=False)
    except Exception:
        xgb_model = XGBRegressor(n_estimators=500, learning_rate=0.05, max_depth=6,
                                 device="cpu", tree_method="hist", verbosity=0,
                                 n_jobs=-1, random_state=SEED)
        xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)],
                      early_stopping_rounds=50, verbose=False)
    timings["XGBoost"] = time.perf_counter() - t0
    results["XGBoost"] = xgb_model.predict(X_test)
    print(f"XGBoost RMSE: {root_mean_squared_error(y_test, results['XGBoost']):,.2f}  ({timings['XGBoost']:.1f}s)")
except Exception as e:
    print(f"XGBoost failed: {e}")
gpu_cleanup()

# Add baseline & FLAML
results["LinearRegression"] = y_pred_bl
results["FLAML"] = y_pred_flaml

# %% [markdown]
# ## 22 · Top 3 Model Selection
#
# Rank all models by RMSE and select the top 3.

# %%
model_scores = {}
for name, yp in results.items():
    model_scores[name] = {
        "RMSE": round(root_mean_squared_error(y_test, yp), 2),
        "MAE": round(mean_absolute_error(y_test, yp), 2),
        "R2": round(r2_score(y_test, yp), 4),
    }

scores_df = pd.DataFrame(model_scores).T.sort_values("RMSE")
print("All Model Rankings (by RMSE):")
print(scores_df.to_string())

top3_names = scores_df.index[:3].tolist()
print(f"\nTop 3 models: {top3_names}")

# %% [markdown]
# ## 23 · Final Training and Evaluation of Top 3
#
# Detailed metrics and predicted-vs-actual plots.

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, name in enumerate(top3_names):
    yp = results[name]
    rmse = root_mean_squared_error(y_test, yp)
    r2 = r2_score(y_test, yp)
    axes[i].scatter(y_test, yp, alpha=0.6, s=20, edgecolors="black", linewidths=0.3)
    mn, mx = y_test.min(), y_test.max()
    axes[i].plot([mn, mx], [mn, mx], "r--", lw=2)
    axes[i].set_title(f"{name}\nRMSE={rmse:,.2f}  R2={r2:.4f}")
    axes[i].set_xlabel("Actual")
    axes[i].set_ylabel("Predicted")

plt.suptitle("Top 3 Models — Predicted vs Actual", fontsize=14)
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, "top3_pred_vs_actual.png"), dpi=120)
plt.show()

print("\nDetailed Metrics — Top 3:")
for name in top3_names:
    yp = results[name]
    print(f"\n  {name}:")
    print(f"    RMSE : {root_mean_squared_error(y_test, yp):,.2f}")
    print(f"    MAE  : {mean_absolute_error(y_test, yp):,.2f}")
    print(f"    R2   : {r2_score(y_test, yp):.4f}")

# %% [markdown]
# ## 24 · Error Analysis
#
# Examine residuals from the best model.

# %%
best_name = top3_names[0]
best_pred = results[best_name]
residuals = y_test.values - best_pred

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].hist(residuals, bins=25, color="steelblue", edgecolor="black", alpha=0.8)
axes[0].axvline(0, color="red", linestyle="--")
axes[0].set_title(f"{best_name} — Residual Distribution")
axes[0].set_xlabel("Residual (Actual - Predicted)")

axes[1].scatter(best_pred, residuals, alpha=0.5, s=15, edgecolors="black", linewidths=0.3)
axes[1].axhline(0, color="red", linestyle="--")
axes[1].set_title(f"{best_name} — Residual vs Predicted")
axes[1].set_xlabel("Predicted"); axes[1].set_ylabel("Residual")

axes[2].scatter(best_pred, np.abs(residuals), alpha=0.5, s=15, edgecolors="black", linewidths=0.3)
axes[2].set_title(f"{best_name} — |Residual| vs Predicted")
axes[2].set_xlabel("Predicted"); axes[2].set_ylabel("|Residual|")

plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, "error_analysis.png"), dpi=120)
plt.show()

print(f"Residual stats ({best_name}):")
print(f"  Mean: {residuals.mean():,.2f}, Std: {residuals.std():,.2f}")
print(f"  Min: {residuals.min():,.2f}, Max: {residuals.max():,.2f}")

# %% [markdown]
# ## 25 · Interpretation and Business Insight
#
# **Key findings:**
# - **Digital spend** has the highest marginal ROI (coefficient on sqrt term).
# - **TV spend** generates the most total sales due to larger budgets, but has strong diminishing returns.
# - **Brand awareness** is a powerful long-term predictor — it captures cumulative marketing effects.
# - **Competitor spend** has a negative impact — higher competitor investment dilutes your share of voice.
# - **Sqrt transforms** of spend channels dramatically improve model fit, confirming diminishing returns.
#
# **Business takeaway:** Shift budget from TV to digital/social for higher marginal ROI. Invest in brand awareness as a long-term multiplier. Monitor competitor spend to anticipate ROI changes.

# %% [markdown]
# ## 26 · Limitations
#
# 1. Synthetic data — real advertising has lagged effects and saturation curves.
# 2. No time series structure — real MMM uses weekly/monthly data over years.
# 3. No media mix interactions — TV + digital synergy is not modeled.
# 4. No attribution modeling — true channel impact requires causal inference.
# 5. Competitor spend is observed but real competitive dynamics are more complex.

# %% [markdown]
# ## 27 · How to Improve This Project
#
# 1. Use real marketing data with time-series structure.
# 2. Add adstock (carryover) effects for each channel.
# 3. Model channel interactions (TV × digital synergy).
# 4. Use Bayesian MMM (e.g., PyMC-Marketing, Lightweight MMM) for uncertainty.
# 5. Include price and promotion as additional marketing levers.

# %% [markdown]
# ## 28 · Production Considerations
#
# - Integrate with marketing dashboards for budget optimization.
# - Update weekly to capture seasonal shifts.
# - Provide confidence intervals on ROI estimates.
# - Run scenario analysis ("what if we shift 20% from TV to digital?").

# %% [markdown]
# ## 29 · Common Mistakes
#
# 1. Using linear spend without diminishing returns transforms — grossly overestimates ROI at high budgets.
# 2. Ignoring multicollinearity between channels (correlated spend).
# 3. Not controlling for brand awareness when estimating channel effects.
# 4. Assuming constant ROI regardless of spend level.
# 5. Confusing correlation (more spend → more sales) with causation (spend causes sales).

# %% [markdown]
# ## 30 · Mini Challenge / Exercises
#
# 1. Remove sqrt transforms and use raw spend — how much does R² drop?
# 2. Calculate marginal ROI for each channel at current average spend level.
# 3. Add TV × digital interaction — does synergy exist?
# 4. Use only the top 3 channels — how close to the full model?
# 5. Double digital spend in test data — what sales increase does the model predict?

# %% [markdown]
# ## 31 · Final Summary / Key Takeaways
#
# 1. **Digital spend** has the highest marginal ROI.
# 2. **Sqrt transforms** capture diminishing returns — essential for marketing models.
# 3. **Brand awareness** is the most impactful long-term predictor.
# 4. **Competitor spend** negatively affects sales — competitive dynamics matter.
# 5. **Gradient boosting** naturally captures non-linear spend-response curves.
# 6. **Real MMM** needs time-series data, adstock effects, and causal inference.

# %% [markdown]
# ## Save Metrics

# %%
metrics_out = {}
for name, yp in results.items():
    metrics_out[name] = {
        "rmse": round(float(root_mean_squared_error(y_test, yp)), 2),
        "mae": round(float(mean_absolute_error(y_test, yp)), 2),
        "r2": round(float(r2_score(y_test, yp)), 4),
    }

metrics_path = os.path.join(SAVE_DIR, "metrics.json")
with open(metrics_path, "w") as f:
    json.dump(metrics_out, f, indent=2)
print(f"Metrics saved to {metrics_path}")
print(json.dumps(metrics_out, indent=2))
